# %%
# General
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import itertools as it

# CV
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import cross_val_score,train_test_split,RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.model_selection import GridSearchCV, ParameterGrid
import time as time

# Models
from sklearn.linear_model import LogisticRegression
from patsy import dmatrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from catboost import CatBoostClassifier

# %%
data = pd.read_csv('./Data/OnlineNewsPopularity.csv')
data.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# 0                   0.815385         4.0              2.0        1.0  ...
# 1                   0.791946         3.0              1.0        1.0  ...
# 2                   0.663866         3.0              1.0        1.0  ...
# 3                   0.665635         9.0              0.0        1.0  ...
# 4                   0.540890        19.0             19.0       20.0  ...
#
#     min_positive_polarity   max_positive_polarity   avg_negative_polarity  \
# 0                0.100000                     0.7               -0.350000
# 1                0.033333                     0.7               -0.118750
# 2                0.100000                     1.0               -0.466667
# 3                0.136364                     0.8               -0.369697
# 4                0.033333                     1.0               -0.220192
#
#     min_negative_polarity   max_negative_polarity   title_subjectivity  \
# 0                  -0.600               -0.200000             0.500000
# 1                  -0.125               -0.100000             0.000000
# 2                  -0.800               -0.133333             0.000000
# 3                  -0.600               -0.166667             0.000000
# 4                  -0.500               -0.050000             0.454545
#
#     title_sentiment_polarity   abs_title_subjectivity  \
# 0                  -0.187500                 0.000000
# 1                   0.000000                 0.500000
# 2                   0.000000                 0.500000
# 3                   0.000000                 0.500000
# 4                   0.136364                 0.045455
#
#     abs_title_sentiment_polarity   shares
# 0                       0.187500      593
# 1                       0.000000      711
# 2                       0.000000     1500
# 3                       0.000000     1200
# 4                       0.136364      505
#
# [5 rows x 61 columns]

# %%
data.describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# count  39644.000000     39644.000000       39644.000000      39644.000000
# mean     354.530471        10.398749         546.514731          0.548216
# std      214.163767         2.114037         471.107508          3.520708
# min        8.000000         2.000000           0.000000          0.000000
# 25%      164.000000         9.000000         246.000000          0.470870
# 50%      339.000000        10.000000         409.000000          0.539226
# 75%      542.000000        12.000000         716.000000          0.608696
# max      731.000000        23.000000        8474.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs  \
# count       39644.000000               39644.000000  39644.000000
# mean            0.996469                   0.689175     10.883690
# std             5.231231                   3.264816     11.332017
# min             0.000000                   0.000000      0.000000
# 25%             1.000000                   0.625739      4.000000
# 50%             1.000000                   0.690476      8.000000
# 75%             1.000000                   0.754630     14.000000
# max          1042.000000                 650.000000    304.000000
#
#         num_self_hrefs      num_imgs    num_videos  ...  \
# count     39644.000000  39644.000000  39644.000000  ...
# mean          3.293638      4.544143      1.249874  ...
# std           3.855141      8.309434      4.107855  ...
# min           0.000000      0.000000      0.000000  ...
# 25%           1.000000      1.000000      0.000000  ...
# 50%           3.000000      1.000000      0.000000  ...
# 75%           4.000000      4.000000      1.000000  ...
# max         116.000000    128.000000     91.000000  ...
#
#         min_positive_polarity   max_positive_polarity   avg_negative_polarity  \
# count            39644.000000            39644.000000            39644.000000
# mean                 0.095446                0.756728               -0.259524
# std                  0.071315                0.247786                0.127726
# min                  0.000000                0.000000               -1.000000
# 25%                  0.050000                0.600000               -0.328383
# 50%                  0.100000                0.800000               -0.253333
# 75%                  0.100000                1.000000               -0.186905
# max                  1.000000                1.000000                0.000000
#
#         min_negative_polarity   max_negative_polarity   title_subjectivity  \
# count            39644.000000            39644.000000         39644.000000
# mean                -0.521944               -0.107500             0.282353
# std                  0.290290                0.095373             0.324247
# min                 -1.000000               -1.000000             0.000000
# 25%                 -0.700000               -0.125000             0.000000
# 50%                 -0.500000               -0.100000             0.150000
# 75%                 -0.300000               -0.050000             0.500000
# max                  0.000000                0.000000             1.000000
#
#         title_sentiment_polarity   abs_title_subjectivity  \
# count               39644.000000             39644.000000
# mean                    0.071425                 0.341843
# std                     0.265450                 0.188791
# min                    -1.000000                 0.000000
# 25%                     0.000000                 0.166667
# 50%                     0.000000                 0.500000
# 75%                     0.150000                 0.500000
# max                     1.000000                 0.500000
#
#         abs_title_sentiment_polarity         shares
# count                   39644.000000   39644.000000
# mean                        0.156064    3395.380184
# std                         0.226294   11626.950749
# min                         0.000000       1.000000
# 25%                         0.000000     946.000000
# 50%                         0.000000    1400.000000
# 75%                         0.250000    2800.000000
# max                         1.000000  843300.000000
#
# [8 rows x 60 columns]

# %%
# Run pip install skimpy if not already installed

from skimpy import clean_columns
data = clean_columns(data)
# Out:
# 60 column names have been cleaned

# %%
# n_unique_tokens is an error
data.iloc[data.n_unique_tokens.argmax()]
# Out:
# url                             http://mashable.com/2014/08/18/ukraine-civilia...
# timedelta                                                                   142.0
# n_tokens_title                                                                9.0
# n_tokens_content                                                           1570.0
# n_unique_tokens                                                             701.0
#                                                       ...
# title_subjectivity                                                            0.0
# title_sentiment_polarity                                                      0.0
# abs_title_subjectivity                                                        0.0
# abs_title_sentiment_polarity                                                  0.0
# shares                                                                       5900
# Name: 31037, Length: 61, dtype: object

# %%
# Also an error
data.iloc[31037].n_non_stop_words
# Out:
# 1042.0

# %%
# Also an error
data.iloc[31037].n_non_stop_unique_tokens
# Out:
# 650.0

# %%
# Transforming

data.iloc[31037, data.columns.get_loc('n_unique_tokens')] = data.n_unique_tokens[31037]/data.n_tokens_content[31037]
data.iloc[31037, data.columns.get_loc('n_non_stop_words')] = data.n_non_stop_words[31037]/data.n_tokens_content[31037]
data.iloc[31037, data.columns.get_loc('n_non_stop_unique_tokens')] = data.n_non_stop_unique_tokens[31037]/data.n_tokens_content[31037]

# %%
data.iloc[31037]
# Out:
# url                             http://mashable.com/2014/08/18/ukraine-civilia...
# timedelta                                                                   142.0
# n_tokens_title                                                                9.0
# n_tokens_content                                                           1570.0
# n_unique_tokens                                                          0.000284
#                                                       ...
# title_subjectivity                                                            0.0
# title_sentiment_polarity                                                      0.0
# abs_title_subjectivity                                                        0.0
# abs_title_sentiment_polarity                                                  0.0
# shares                                                                       5900
# Name: 31037, Length: 61, dtype: object

# %%
data.describe()
# Out:
#           timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# count  39644.000000    39644.000000      39644.000000     39644.000000
# mean     354.530471       10.398749        546.514731         0.530545
# std      214.163767        2.114037        471.107508         0.137111
# min        8.000000        2.000000          0.000000         0.000000
# 25%      164.000000        9.000000        246.000000         0.470858
# 50%      339.000000       10.000000        409.000000         0.539216
# 75%      542.000000       12.000000        716.000000         0.608696
# max      731.000000       23.000000       8474.000000         1.000000
#
#        n_non_stop_words  n_non_stop_unique_tokens     num_hrefs  \
# count      39644.000000              39644.000000  39644.000000
# mean           0.970201                  0.672790     10.883690
# std            0.170017                  0.154039     11.332017
# min            0.000000                  0.000000      0.000000
# 25%            1.000000                  0.625720      4.000000
# 50%            1.000000                  0.690476      8.000000
# 75%            1.000000                  0.754620     14.000000
# max            1.000000                  1.000000    304.000000
#
#        num_self_hrefs      num_imgs    num_videos  ...  min_positive_polarity  \
# count    39644.000000  39644.000000  39644.000000  ...           39644.000000
# mean         3.293638      4.544143      1.249874  ...               0.095446
# std          3.855141      8.309434      4.107855  ...               0.071315
# min          0.000000      0.000000      0.000000  ...               0.000000
# 25%          1.000000      1.000000      0.000000  ...               0.050000
# 50%          3.000000      1.000000      0.000000  ...               0.100000
# 75%          4.000000      4.000000      1.000000  ...               0.100000
# max        116.000000    128.000000     91.000000  ...               1.000000
#
#        max_positive_polarity  avg_negative_polarity  min_negative_polarity  \
# count           39644.000000           39644.000000           39644.000000
# mean                0.756728              -0.259524              -0.521944
# std                 0.247786               0.127726               0.290290
# min                 0.000000              -1.000000              -1.000000
# 25%                 0.600000              -0.328383              -0.700000
# 50%                 0.800000              -0.253333              -0.500000
# 75%                 1.000000              -0.186905              -0.300000
# max                 1.000000               0.000000               0.000000
#
#        max_negative_polarity  title_subjectivity  title_sentiment_polarity  \
# count           39644.000000        39644.000000              39644.000000
# mean               -0.107500            0.282353                  0.071425
# std                 0.095373            0.324247                  0.265450
# min                -1.000000            0.000000                 -1.000000
# 25%                -0.125000            0.000000                  0.000000
# 50%                -0.100000            0.150000                  0.000000
# 75%                -0.050000            0.500000                  0.150000
# max                 0.000000            1.000000                  1.000000
#
#        abs_title_subjectivity  abs_title_sentiment_polarity         shares
# count            39644.000000                  39644.000000   39644.000000
# mean                 0.341843                      0.156064    3395.380184
# std                  0.188791                      0.226294   11626.950749
# min                  0.000000                      0.000000       1.000000
# 25%                  0.166667                      0.000000     946.000000
# 50%                  0.500000                      0.000000    1400.000000
# 75%                  0.500000                      0.250000    2800.000000
# max                  0.500000                      1.000000  843300.000000
#
# [8 rows x 60 columns]

# %%
data['avg_shares_per_day'] = data['shares']/data['timedelta']
data.head()
# Out:
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...      731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...      731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...      731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...      731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/      731.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  ...  \
# 0                  0.815385        4.0             2.0       1.0  ...
# 1                  0.791946        3.0             1.0       1.0  ...
# 2                  0.663866        3.0             1.0       1.0  ...
# 3                  0.665635        9.0             0.0       1.0  ...
# 4                  0.540890       19.0            19.0      20.0  ...
#
#    max_positive_polarity  avg_negative_polarity  min_negative_polarity  \
# 0                    0.7              -0.350000                 -0.600
# 1                    0.7              -0.118750                 -0.125
# 2                    1.0              -0.466667                 -0.800
# 3                    0.8              -0.369697                 -0.600
# 4                    1.0              -0.220192                 -0.500
#
#    max_negative_polarity  title_subjectivity  title_sentiment_polarity  \
# 0              -0.200000            0.500000                 -0.187500
# 1              -0.100000            0.000000                  0.000000
# 2              -0.133333            0.000000                  0.000000
# 3              -0.166667            0.000000                  0.000000
# 4              -0.050000            0.454545                  0.136364
#
#    abs_title_subjectivity  abs_title_sentiment_polarity  shares  \
# 0                0.000000                      0.187500     593
# 1                0.500000                      0.000000     711
# 2                0.500000                      0.000000    1500
# 3                0.500000                      0.000000    1200
# 4                0.045455                      0.136364     505
#
#    avg_shares_per_day
# 0            0.811218
# 1            0.972640
# 2            2.051984
# 3            1.641587
# 4            0.690834
#
# [5 rows x 62 columns]

# %%
np.median(data.avg_shares_per_day)
# Out:
# 5.6131399928392405

# %%
data['popular'] = data.avg_shares_per_day.apply(lambda x: 1 if x > np.median(data.avg_shares_per_day)
                                    else 0)

# %%
data.to_csv('classification_data.csv', index = False)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data.drop(['shares', 'url', 'popular', 'timedelta', 'avg_shares_per_day'], axis = 1),
    data['popular'],
    test_size = 0.2,
    random_state = 42)

print(X_train.shape)
print(X_test.shape)
# Out:
# (31715, 58)
# (7929, 58)

# %% [markdown]
# # CatBoost Feature Selection

# %%
mod = CatBoostClassifier(silent = True).fit(X_train, y_train)

# %%
feature_importances = pd.DataFrame(columns = ['Predictor', 'Importance'])
feature_importances['Predictor'] = X_train.columns
feature_importances['Importance'] = mod.feature_importances_
feature_importances.sort_values(by = 'Importance', ascending = False, inplace = True)

# %%
feature_importances
# Out:
#                         Predictor  Importance
# 17                     kw_min_min   19.999903
# 24                     kw_max_avg    9.343322
# 19                     kw_avg_min    3.423716
# 22                     kw_avg_max    3.326570
# 25                     kw_avg_avg    2.948959
# 18                     kw_max_min    2.766082
# 26      self_reference_min_shares    2.570225
# 7                        num_imgs    2.435495
# 38                         lda_01    2.341883
# 41                         lda_04    2.232416
# 2                 n_unique_tokens    2.071048
# 23                     kw_min_avg    2.068627
# 37                         lda_00    2.007099
# 4        n_non_stop_unique_tokens    1.980577
# 39                         lda_02    1.936841
# 1                n_tokens_content    1.927672
# 5                       num_hrefs    1.814643
# 40                         lda_03    1.802017
# 42            global_subjectivity    1.775928
# 0                  n_tokens_title    1.723122
# 48          avg_positive_polarity    1.694264
# 6                  num_self_hrefs    1.677711
# 9            average_token_length    1.507173
# 20                     kw_min_max    1.489775
# 44     global_rate_positive_words    1.368504
# 8                      num_videos    1.360204
# 28     self_reference_avg_sharess    1.327475
# 43      global_sentiment_polarity    1.280303
# 51          avg_negative_polarity    1.242452
# 45     global_rate_negative_words    1.119905
# 36                     is_weekend    1.092270
# 27      self_reference_max_shares    1.046938
# 15           data_channel_is_tech    1.024572
# 49          min_positive_polarity    0.961513
# 55       title_sentiment_polarity    0.928348
# 12  data_channel_is_entertainment    0.850801
# 47            rate_negative_words    0.826599
# 21                     kw_max_max    0.824751
# 54             title_subjectivity    0.794188
# 56         abs_title_subjectivity    0.761691
# 14         data_channel_is_socmed    0.692296
# 53          max_negative_polarity    0.688795
# 57   abs_title_sentiment_polarity    0.635861
# 46            rate_positive_words    0.565402
# 52          min_negative_polarity    0.541529
# 50          max_positive_polarity    0.470055
# 10                   num_keywords    0.364486
# 33              weekday_is_friday    0.353031
# 31           weekday_is_wednesday    0.340471
# 30             weekday_is_tuesday    0.326781
# 29              weekday_is_monday    0.259011
# 34            weekday_is_saturday    0.252731
# 13            data_channel_is_bus    0.242722
# 16          data_channel_is_world    0.222768
# 11      data_channel_is_lifestyle    0.137877
# 32            weekday_is_thursday    0.123867
# 3                n_non_stop_words    0.061546
# 35              weekday_is_sunday    0.045191

# %%
# To include only the top 80%
feats = list(feature_importances[feature_importances.Importance >= np.quantile(feature_importances.Importance, 0.2)].Predictor)

# %%
data_dropped = pd.concat([data.loc[:, feats], data.popular], axis = 1)

# %%
data_dropped.shape
# Out:
# (39644, 47)

# %%
data_dropped.to_csv('data_dropped.csv', index = False)
